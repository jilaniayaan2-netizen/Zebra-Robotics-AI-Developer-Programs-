# %%
import numpy as np 

arr = np.array([[[73, 25, 88, 41],[67, 52, 33, 90],[16, 78, 59, 28]],[[44, 66, 71, 39],[85, 19, 63, 97],[58, 23, 31, 49]]])
newArr = arr.astype('float32')

print("The array's shape is", arr.shape)
print("The array has", arr.ndim, "dimension(s).")
print("The array's data type is", arr.dtype)
print("The third element in the second row of the first 2D array is", arr[0,1,2])
for x in range(0,3):
    print("2D array 1, row", x+1 ,arr[0,x,0:2]) 
for x in range(0,3):
    print("2D array 2, row", x+1 ,arr[1,x,0:2]) 
print(newArr.dtype)
# Out:
# The array's shape is (2, 3, 4)
# The array has 3 dimension(s).
# The array's data type is int64
# The third element in the second row of the first 2D array is 33
# 2D array 1, row 1 [73 25]
# 2D array 1, row 2 [67 52]
# 2D array 1, row 3 [16 78]
# 2D array 2, row 1 [44 66]
# 2D array 2, row 2 [85 19]
# 2D array 2, row 3 [58 23]
# float32
